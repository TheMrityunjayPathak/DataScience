# %% [markdown]
# *Importing Essential Package*
#
# *%matplotlib inline command is a magic command that makes the plots generated by matplotlib show into the IPython shell that we are running and not in a separate output window*

# %%
from matplotlib import pyplot as plt
from matplotlib import style
import numpy as np
# %matplotlib inline

# %% [markdown]
# *Creating NumPy Array and Storing it in xpoints,ypoints Variables*
#
# *Using **plt.plot(xpoints,ypoints)** to map points on X and Y Axis*
#
# *Using **plt.show()** to get the Output*

# %% [markdown]
# *By default, the **plt.plot()** function draws a line from point to point.*

# %% [markdown]
# *You can plot as many points as you like, just make sure you have the same number of points in both axis*

# %%
xpoints = np.array([1,2,3,4,5,6])
ypoints = np.array([3,6,9,12,15,18])
plt.plot(xpoints,ypoints)
plt.show()

# %% [markdown]
# *If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 etc (depending on the length of the y-points)*

# %%
ypoints = np.array([3,1,9,2,15,8])
plt.plot(ypoints)
plt.show()

# %% [markdown]
# *You can use the keyword argument **marker** to emphasize each point with a specified marker*

# %%
xpoints = np.array([3,10,8,1])
ypoints = np.array([2,5,7,11])
plt.plot(xpoints,ypoints,marker = 'o')
plt.show()

# %% [markdown]
# *You can also insert **Markers** in a plot without using marker argument*

# %%
xpoints = np.array([4,8,7,1])
ypoints = np.array([3,6,11,9])
plt.plot(xpoints,ypoints,'*')
plt.show()

# %% [markdown]
# *You can use also use the shortcut string notation parameter to specify the marker*
#
# *This parameter is also called **fmt**, and is written with this syntax:*
#
# **marker|line|color**
#
# **You can choose any of these markers:**
#
# **'o' Circle**
#
# **'*' Star**
#
# **'.' Point**
#
# **',' Pixel**
#
# **'x' X**
#
# **'X' X (filled)**
#
# **'+' Plus**
#
# **'P' Plus (filled)**
#
# **'s' Square**
#
# **'D' Diamond**
#
# **'d' Diamond (thin)**
#
# **'p' Pentagon**
#
# **'H' Hexagon**
#
# **'h' Hexagon**
#
# **'v' Triangle Down**
#
# **'^' Triangle Up**
#
# **'<' Triangle Left**
#
# **'>' Triangle Right**
#
# **'1' Tri Down**
#
# **'2' Tri Up**
#
# **'3' Tri Left**
#
# **'4' Tri Right**
#
# **'|' Vline**
#
# **'_' Hline**

# %% [markdown]
# **The line value can be one of the following:**
#
# **'-' Solid line**
#
# **':' Dotted line**
#
# **'--' Dashed line**
#
# **'-.' Dashed/dotted line**

# %% [markdown]
# **The short color value can be one of the following:**
#
# **'r' Red**
#
# **'g' Green**
#
# **'b' Blue**
#
# **'c' Cyan**
#
# **'m' Magenta**
#
# **'y' Yellow**
#
# **'k' Black**
#
# **'w' White**

# %%
xpoints = np.array([3,10,8,1])
ypoints = np.array([2,5,7,11])
plt.plot(xpoints,ypoints,'o--g')
plt.show()

# %% [markdown]
# *You can use the keyword argument markersize or the shorter version, **ms** to set the size of the markers*

# %%
ypoints = np.array([3,1,9,2,15,8])
plt.plot(ypoints,marker = 'o',ms = '15')
plt.show()

# %% [markdown]
# *You can use the keyword argument markeredgecolor or the shorter **mec** to set the color of the edge of the markers*

# %%
ypoints = np.array([3,1,9,2,15,8])
plt.plot(ypoints,marker = 'o',ms = '15',mec = 'r')
plt.show()

# %% [markdown]
# *You can use the keyword argument markerfacecolor or the shorter **mfc** to set the color inside the edge of the markers*

# %%
ypoints = np.array([3,1,9,2,15,8])
plt.plot(ypoints,marker = 'o',ms = '15',mfc = 'r')
plt.show()

# %% [markdown]
# *Use both the **mec** and **mfc** arguments to color the entire **marker***

# %%
ypoints = np.array([3,1,9,2,15,8])
plt.plot(ypoints,marker = 'o',ms = '15',mec = 'r',mfc = 'r')
plt.show()

# %% [markdown]
# *You can also use **Hexadecimal** color values*
#
# https://www.w3schools.com/colors/colors_names.asp

# %%
ypoints = np.array([3,1,9,2,15,8])
plt.plot(ypoints,marker = 'o',ms = '15',mec = '#4CAF50',mfc = '#4CAF50')
plt.show()

# %% [markdown]
# *You can also use any of the **140** supported color names*
#
# https://www.w3schools.com/colors/colors_names.asp

# %%
ypoints = np.array([3,1,9,2,15,8])
plt.plot(ypoints,marker = 'o',ms = '15',mec = 'coral',mfc = 'aqua')
plt.show()

# %% [markdown]
# *You can use the keyword argument **linestyle**, or shorter **ls**, to change the **style** of the plotted line*
#
# *The **linestyle** are of following types:*
#
# **dotted dashed dashdot solid none**

# %%
xpoints = np.array([4,8])
ypoints = np.array([3,6])
plt.plot(xpoints,ypoints,linestyle = 'dotted')
plt.show()

# %% [markdown]
# *You can use the keyword argument **color** or the shorter **c** to set the color of the line*

# %%
ypoints = np.array([3,1,9,2,15,8])
plt.plot(ypoints,color = 'r')
plt.show()

# %% [markdown]
# *You can also use **Hexadecimal** color values*

# %%
ypoints = np.array([3,1,9,2,15,8])
plt.plot(ypoints,color = '#4CAF50')
plt.show()

# %% [markdown]
# *You can also use any of the **140** supported color names*

# %%
ypoints = np.array([3,1,9,2,15,8])
plt.plot(ypoints,color = 'hotpink')
plt.show()

# %% [markdown]
# *You can use the keyword argument **linewidth** or the shorter **lw** to change the width of the line*

# %%
ypoints = np.array([3,1,9,2,15,8])
plt.plot(ypoints,linewidth = '5')
plt.show()

# %% [markdown]
# *You can plot as many lines as you like by simply adding more **plt.plot()** functions*

# %%
xpoints = np.array([3,10,8,1])
ypoints = np.array([2,5,7,11])
plt.plot(xpoints)
plt.plot(ypoints)
plt.show()

# %% [markdown]
# *With Pyplot, you can use the **xlabel()** and **ylabel()** functions to set a label for the x-axis and y-axis*

# %%
xpoints = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
ypoints = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(xpoints, ypoints)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %% [markdown]
# *With Pyplot, you can use the **title()** function to set a title for the plot*

# %%
xpoints = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
ypoints = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(xpoints, ypoints)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.title("FitBit Data")
plt.show()

# %% [markdown]
# *You can use the **fontdict** parameter in **xlabel()**, **ylabel()**, and **title()** to set font properties for the title and labels*

# %%
xpoints = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
ypoints = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(xpoints, ypoints)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.xlabel("Average Pulse",fontdict = font2)
plt.ylabel("Calorie Burnage",fontdict = font2)
plt.title("FitBit Data",fontdict = font1)
plt.show()

# %% [markdown]
# *You can use the **loc** parameter in **title()** to position the title*
#
# *Legal values are: 'left', 'right', and 'center'*
#
# *Default value is 'center'*

# %%
xpoints = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
ypoints = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(xpoints, ypoints)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.xlabel("Average Pulse",fontdict = font2)
plt.ylabel("Calorie Burnage",fontdict = font2)
plt.title("FitBit Data",fontdict = font1,loc = 'left')
plt.show()

# %% [markdown]
# *With Pyplot, you can use the **grid()** function to add grid lines to the plot*

# %%
xpoints = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
ypoints = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(xpoints, ypoints)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.xlabel("Average Pulse",fontdict = font2)
plt.ylabel("Calorie Burnage",fontdict = font2)
plt.title("FitBit Data",fontdict = font1,loc = 'left')
plt.grid()
plt.show()

# %% [markdown]
# *You can use the **axis** parameter in the **grid()** function to specify which grid lines to display*
#
# *Legal values are: 'x', 'y', and 'both'*
#
# *Default value is 'both'*

# %%
xpoints = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
ypoints = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(xpoints, ypoints)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.xlabel("Average Pulse",fontdict = font2)
plt.ylabel("Calorie Burnage",fontdict = font2)
plt.title("FitBit Data",fontdict = font1,loc = 'left')
plt.grid(axis = 'x')
plt.show()

# %%
xpoints = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
ypoints = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(xpoints, ypoints)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.xlabel("Average Pulse",fontdict = font2)
plt.ylabel("Calorie Burnage",fontdict = font2)
plt.title("FitBit Data",fontdict = font1,loc = 'left')
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# *You can also set the line properties of the grid*

# %%
xpoints = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
ypoints = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(xpoints, ypoints)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.xlabel("Average Pulse",fontdict = font2)
plt.ylabel("Calorie Burnage",fontdict = font2)
plt.title("FitBit Data",fontdict = font1,loc = 'left')
plt.grid(color = 'hotpink', linestyle = ':', linewidth = 1)
plt.show()

# %% [markdown]
# *With the **subplot()** function you can draw multiple plots in one figure*
#
# *The **subplot()** function takes three arguments that describes the layout of the figure*
#
# *The layout is organized in **rows** and **columns**, which are represented by the **first** and **second** argument*
#
# *The **third** argument represents the **index** of the current plot*

# %%
#plot 1:
x = np.array([1, 3, 5, 11])
y = np.array([3, 7, 1, 9])
plt.subplot(1, 2, 1)
#the figure has 1 row, 2 columns, and this plot is the first plot
plt.plot(x,y)

#plot 2:
x = np.array([12, 11, 2, 13])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
#the figure has 1 row, 2 columns, and this plot is the second plot
plt.plot(x,y)

plt.show()

# %% [markdown]
# *So, if we want a figure with 2 rows an 1 column (meaning that the two plots will be displayed on top of each other instead of side-by-side)*

# %%
#plot 1:
x = np.array([1, 3, 5, 11])
y = np.array([3, 7, 1, 9])
plt.subplot(2, 1, 1)
#the figure has 2 row, 1 columns, and this plot is the first plot
plt.plot(x,y)

#plot 2:
x = np.array([12, 11, 2, 13])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 1, 2)
#the figure has 2 row, 1 columns, and this plot is the second plot
plt.plot(x,y)

plt.show()

# %% [markdown]
# *You can draw as many plots you like on one figure, just descibe the number of rows, columns, and the index of the plot*

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([1, 7, 2, 9])
y = np.array([3, 4, 11, 13])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([12, 20, 3, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([6, 20, 12, 4])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# *You can add a title to each plot with the **title()** function*

# %%
#plot 1:
x = np.array([1, 3, 5, 11])
y = np.array([3, 7, 1, 9])
plt.subplot(1, 2, 1)
#the figure has 1 row, 2 columns, and this plot is the first plot
plt.plot(x,y)
plt.title("Profit")

#plot 2:
x = np.array([12, 11, 2, 13])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
#the figure has 1 row, 2 columns, and this plot is the second plot
plt.plot(x,y)
plt.title("Loss")

plt.show()

# %% [markdown]
# *You can add a title to the entire figure with the **suptitle()** function*

# %%
#plot 1:
x = np.array([1, 3, 5, 11])
y = np.array([3, 7, 1, 9])
plt.subplot(1, 2, 1)
#the figure has 1 row, 2 columns, and this plot is the first plot
plt.plot(x,y)
plt.title("Profit")

#plot 2:
x = np.array([12, 11, 2, 13])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
#the figure has 1 row, 2 columns, and this plot is the second plot
plt.plot(x,y)
plt.title("Loss")

plt.suptitle("My Grocery Store")
plt.show()

# %% [markdown]
# *With Pyplot, you can use the **scatter()** function to draw a scatter plot*
#
# *The **scatter()** function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis*
#
# *The observation in the example above is the result of 13 cars passing by*
#
# *The X-axis shows how old the car is*
#
# *The Y-axis shows the speed of the car when it passes*

# %%
xpoints = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
ypoints = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(xpoints,ypoints)
plt.show()

# %% [markdown]
# *The two plots are plotted with two different colors, by default blue and orange*

# %%
#day one, the age and speed of 13 cars:
x1points = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y1points = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x1points, y1points)

#day two, the age and speed of 15 cars:
x2points = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y2points = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x2points, y2points)

plt.show()

# %% [markdown]
# *You can set your own color for each scatter plot with the **color** or the **c** argument*

# %%
x1points = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y1points = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x1points, y1points, color = 'hotpink')

x2points = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y2points = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x2points, y2points, color = '#88c999')

plt.show()

# %% [markdown]
# *You can even set a specific color for each dot by using an **array** of **colors** as value for the **c** argument*

# %%
xpoints = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
ypoints = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","coral","brown","gray","aqua","magenta"])
plt.scatter(xpoints, ypoints, c=colors)
plt.show()

# %% [markdown]
# *The Matplotlib module has a number of available **colormaps***
#
# *A **colormap** is like a list of colors, where each color has a value that ranges from 0 to 100*
#
# *This colormap is called **'viridis'** and as you can see it ranges from 0, which is a **purple** color, up to 100, which is a **yellow** color*
#
# *You can specify the colormap with the keyword argument cmap with the value of the colormap, in this case 'viridis' which is one of the built-in colormaps available in Matplotlib*
#
# *In addition you have to create an array with values (from 0 to 100), one value for each point in the scatter plot*

# %%
xpoints = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
ypoints = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(xpoints, ypoints, c=colors, cmap='viridis')

plt.show()

# %% [markdown]
# *You can include the colormap in the drawing by including the **plt.colorbar()** statement*

# %%
xpoints = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
ypoints = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(xpoints, ypoints, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# *You can change the size of the dots with the **s** argument*
#
# *Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis*

# %%
xpoints = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
ypoints = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(xpoints, ypoints, s=sizes)

plt.show()

# %% [markdown]
# *You can adjust the transparency of the dots with the **alpha** argument*
#
# *Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis*

# %%
xpoints = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
ypoints = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(xpoints, ypoints, s=sizes, alpha=0.5)

plt.show()

# %% [markdown]
# *With Pyplot, you can use the **bar()** function to draw bar graphs*

# %%
xpoints = np.array(["A", "B", "C", "D"])
ypoints = np.array([6, 8, 1, 5])

plt.bar(xpoints,ypoints)

plt.show()

# %% [markdown]
# *If you want the bars to be displayed horizontally instead of vertically, use the **barh()** function*

# %%
xpoints = np.array(["A", "B", "C", "D"])
ypoints = np.array([6, 8, 1, 5])

plt.barh(xpoints,ypoints)

plt.show()

# %% [markdown]
# *The **bar()** and **barh()** take the keyword argument **color** to set the color of the bars*
#
# *You can use any of the **140** supported color names*
#
# *You can also use **Hexadecimal** color values*

# %%
xpoints = np.array(["A", "B", "C", "D"])
ypoints = np.array([6, 8, 1, 5])

plt.bar(xpoints,ypoints,color = 'red')

plt.show()

# %%
xpoints = np.array(["A", "B", "C", "D"])
ypoints = np.array([6, 8, 1, 5])

plt.barh(xpoints,ypoints,color = 'green')

plt.show()

# %% [markdown]
# *The **bar()** takes the keyword argument **width** to set the width of the bars*
#
# *The **default** width value is 0.8*

# %%
xpoints = np.array(["A", "B", "C", "D"])
ypoints = np.array([6, 8, 1, 5])

plt.bar(xpoints,ypoints,width = 0.2)

plt.show()

# %% [markdown]
# *For horizontal bars, use **height** instead of **width***
#
# *The **barh()** takes the keyword argument **height** to set the height of the bars*
#
# *The **default** height value is 0.8*

# %%
xpoints = np.array(["A", "B", "C", "D"])
ypoints = np.array([6, 8, 1, 5])

plt.barh(xpoints,ypoints,height = 0.2)

plt.show()

# %% [markdown]
# *In Matplotlib, we use the **hist()** function to create histograms*
#
# *The **hist()** function will use an array of numbers to create a histogram, the array is sent into the function as an argument*

# %%
x = np.random.normal(170, 10, 250)
print(x)
# Out:
# [184.71455431 165.59727489 195.21467311 164.2358692  167.0300571
#  161.18186066 167.65516701 182.82158883 193.3965366  170.52855403
#  163.83757857 162.96038012 155.21436142 167.87528987 181.12956263
#  175.58169627 169.62082584 155.18729625 166.33993286 170.84557064
#  162.02601454 163.79480274 184.60775662 183.16878117 164.62592967
#  172.91170513 168.51581656 191.61131198 170.88185731 169.74477128
#  159.76278984 176.19681167 169.64742306 165.76163416 196.20286749
#  156.09632809 170.40720156 171.34975375 170.10547101 170.6139661
#  170.29626495 164.46576683 169.93728374 150.42173544 157.71157717
#  170.97728539 163.76920277 165.80226406 175.49615452 161.0986876
#  164.39990144 174.74010013 172.84678243 163.46473103 150.78054895
#  176.63484757 158.60147892 168.31905171 162.89462368 167.50953429
#  172.03470388 158.50535602 151.4598333  157.09437977 175.75123629
#  166.06467387 160.08346598 176.1355607  180.63364589 167.85901036
#  169.73267707 185.90859397 178.84726901 175.97555189 190.08056739
#  182.46789381 178.22222323 162.63421295 174.73067521 178.94342447
#  154.79027318 166.59065118 177.07336197 165.90200235 163.7221366
#  167.76549651 161.24793203 166.17820362 177.51554752 168.05512608
#  164.46116582 168.29196712 178.98107579 169.72810965 163.75184276
#  175.90880914 171.814733   174.04459215 172.85879065 175.57928216
#  190.27156962 164.11177125 167.77944567 173.11252533 164.35783487
#  190.02009099 176.37757192 173.62762561 186.90859388 179.18038879
#  168.33536921 167.35004664 160.31039639 168.75797342 176.97580649
#  190.0021626  183.08474106 168.46731552 157.36936827 183.91633979
#  161.86956342 173.67719058 164.63511657 169.1028366  171.31914519
#  178.90862065 196.44005772 166.76679796 171.25898001 176.66668395
#  172.6802642  163.63850965 193.61693726 168.17899958 154.25958455
#  172.42595736 169.05432286 174.41985811 167.3095223  178.44393628
#  178.12236588 181.13711141 167.0490761  182.81215838 162.739305
#  167.76597293 171.77319006 176.97027351 185.43683644 180.23749577
#  167.92526403 173.84468317 169.40041127 171.08576768 167.29156842
#  169.81113918 177.69649105 164.42344683 183.93829101 167.28751347
#  165.53879945 185.51990933 158.43970367 174.82524574 179.40411251
#  160.11832563 166.80067921 146.58586697 172.13710582 166.32244459
#  175.78920147 163.07567075 166.8490112  168.47958519 158.48890513
#  170.56197918 158.06425927 167.82032043 183.15302752 180.68110969
#  176.51292581 164.04448017 167.85673671 179.17200716 168.13396755
#  173.55251643 171.87066024 177.12121746 179.54101637 163.73718063
#  163.53729488 168.65330118 163.54220113 178.4875753  170.63378675
#  177.68340353 186.59279407 171.97999166 180.99680075 187.26145782
#  159.15574941 168.77791561 178.66920922 180.87320938 179.25195146
#  160.10478004 176.16941995 173.39589447 166.00172467 150.48714473
#  177.12738548 174.30424365 169.88413927 175.37383557 189.01238301
#  159.37652555 169.03632141 191.35984845 162.45782632 151.63334667
#  173.70863104 175.23418554 156.09323618 181.77504225 175.10466571
#  167.11838963 174.33207354 158.62067713 150.67820275 159.26726337
#  173.00241733 165.53138355 178.71298522 185.13891632 178.7320093
#  170.8707101  189.40030039 165.80944603 163.11916338 153.28163527
#  166.16498407 176.92516417 164.95997307 168.34825902 187.38703269
#  162.49977229 171.76000775 176.27533014 178.39919237 176.18905477]

# %% [markdown]
# *The **hist()** function will read the array and produce a histogram*

# %%
x = np.random.normal(170, 10, 250)
plt.hist(x)
plt.show()

# %% [markdown]
# *With Pyplot, you can use the **pie()** function to draw pie charts*
#
# *By default the plotting of the first wedge starts from the x-axis and moves counterclockwise*

# %%
ypoints = np.array([35, 25, 25, 15])
plt.pie(ypoints)
plt.show()

# %% [markdown]
# *Add **labels** to the pie chart with the **label** parameter*
#
# *The label parameter must be an array with one label for each wedge*

# %%
ypoints = np.array([35, 25, 25, 15])
mylabels = ["Maths", "English", "Physics", "Chemistry"]
plt.pie(ypoints, labels = mylabels)
plt.show()

# %% [markdown]
# *As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter*
#
# *The startangle parameter is defined with an angle in degrees, default angle is 0*

# %%
ypoints = np.array([35, 25, 25, 15])
mylabels = ["Maths", "English", "Physics", "Chemistry"]
plt.pie(ypoints, labels = mylabels,startangle = 90)
plt.show()

# %% [markdown]
# *The **explode** parameter allows you to stand out a wedge of pie*

# %%
ypoints = np.array([35, 25, 25, 15])
mylabels = ["Maths", "English", "Physics", "Chemistry"]
myexplode = [0.2, 0, 0, 0]
plt.pie(ypoints, labels = mylabels,explode = myexplode)
plt.show()

# %% [markdown]
# *Add a **shadow** to the pie chart by setting the **shadows** parameter to **True***

# %%
ypoints = np.array([35, 25, 25, 15])
mylabels = ["Maths", "English", "Physics", "Chemistry"]
myexplode = [0.2, 0, 0, 0]
plt.pie(ypoints, labels = mylabels,explode = myexplode,shadow = True)
plt.show()

# %% [markdown]
# *You can set the **color** of each wedge with the **colors** parameter*
#
# *The colors parameter, if specified, must be an array with one value for each wedge*

# %%
ypoints = np.array([35, 25, 25, 15])
mylabels = ["Maths", "English", "Physics", "Chemistry"]
mycolors = ["coral", "hotpink", "b", "#4CAF50"]
plt.pie(ypoints, labels = mylabels,colors = mycolors)
plt.show()

# %% [markdown]
# *To add a list of explanation for each wedge, use the **legend()** function*

# %%
ypoints = np.array([35, 25, 25, 15])
mylabels = ["Maths", "English", "Physics", "Chemistry"]
plt.pie(ypoints, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# *To add a header to the legend, add the **title** parameter to the legend function*

# %%
ypoints = np.array([35, 25, 25, 15])
mylabels = ["Maths", "English", "Physics", "Chemistry"]
plt.pie(ypoints, labels = mylabels)
plt.legend(title = "Subject:")
plt.show()
